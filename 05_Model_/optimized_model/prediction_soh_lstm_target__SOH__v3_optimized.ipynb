# %% [markdown]
# # 🛰️ CubeSat EPS — Prédiction directe du SOH avec LSTM
# ### Features depuis `features.pkl` · Cible = **SOH brut** (sans normalisation de la cible)
#
# > **Correction principale** : `scaler_y` supprimé.
# > Le SOH ∈ [0, 1] par définition physique — le normaliser sur le train seul
# > pousse les valeurs du val set (SOH plus dégradé) en zone négative,
# > ce qui bloque l'apprentissage dès l'époque 0.
#
# | # | Section |
# |---|---------|
# | 1 | Imports |
# | 2 | Chemins & configuration |
# | 3 | Chargement de `features.pkl` |
# | 4 | Chargement & tri des données |
# | 5 | Feature engineering |
# | 6 | Vérification des features |
# | 7 | Split chronologique 80 / 20 |
# | 8 | Normalisation des features X uniquement |
# | 9 | Construction des séquences |
# | 10 | Architecture LSTM |
# | 11 | Entraînement |
# | 12 | Prédiction |
# | 13 | Évaluation |
# | 14 | Visualisations |
# | 15 | Sauvegarde |

# %%
import os, random
os.environ['PYTHONHASHSEED']       = '42'
os.environ['TF_DETERMINISTIC_OPS'] = '1'

import numpy as np
import tensorflow as tf

random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ## 1 — Imports

# %%
import os, pickle, joblib, warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, LayerNormalization, Lambda
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    mean_squared_error, mean_absolute_error,
    r2_score, explained_variance_score, max_error,
)
from tensorflow.keras.layers import (
    LSTM, Dense, Dropout, LayerNormalization,
    MultiHeadAttention, GlobalAveragePooling1D,
)

print(f'TensorFlow : {tf.__version__}')
print(f'GPU        : {tf.config.list_physical_devices("GPU")}')
# Out:
# TensorFlow : 2.20.0
# GPU        : [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2 — Chemins & configuration

# %%
# ── Option A : Colab — upload manuel ──────────────────────────────────────
# from google.colab import files
# files.upload()
# DATA_PATH     = 'battery_dataset_normal.csv'
# FEATURES_PATH = 'features.pkl'

# ── Option B : Colab + Google Drive ───────────────────────────────────────
# from google.colab import drive
# drive.mount('/content/drive')
BASE          = '/content/drive/MyDrive/Colab Notebooks/dataset_1'
DATA_PATH     = f'{BASE}/battery_dataset_normal.csv'
FEATURES_PATH = f'{BASE}/features.pkl'

# ── Option C : chemin local ────────────────────────────────────────────────
#DATA_PATH     = 'battery_dataset_normal.csv'
#FEATURES_PATH = 'features.pkl'

OUTPUT_DIR  = '/content/drive/MyDrive/Colab Notebooks/outputs_1'
os.makedirs(OUTPUT_DIR, exist_ok=True)

ROLLING_W   = 10
WINDOW_SIZE = 30
STEP_SIZE   = 3
HORIZON     = 1
TRAIN_FRAC  = 0.80
BATCH_SIZE  = 64
MAX_EPOCHS  = 400

print(f'Output  : {OUTPUT_DIR}/')
print(f'Cible   : SOH brut — aucune normalisation de la cible')
# Out:
# Output  : /content/drive/MyDrive/Colab Notebooks/outputs_1/
# Cible   : SOH brut — aucune normalisation de la cible

# %% [markdown]
# ## 3 — Chargement de `features.pkl`

# %%
with open(FEATURES_PATH, 'rb') as f:
    FEATURE_COLS = pickle.load(f)

print(f'{len(FEATURE_COLS)} features :')
for i, feat in enumerate(FEATURE_COLS):
    print(f'  [{i:02d}] {feat}')
# Out:
# 20 features :
#   [00] V_mean_V
#   [01] V_spread
#   [02] V_mean_rolling
#   [03] V_mean_lag_1
#   [04] V_min_fade
#   [05] Tavg_C
#   [06] thermal_range
#   [07] delta_T_ambient
#   [08] cold_cycle_count
#   [09] Tavg_rolling
#   [10] eclipse_flag
#   [11] QD_Ah
#   [12] coulombic_eff
#   [13] discharge_C_rate
#   [14] capacity_retention
#   [15] QD_rolling
#   [16] cycle
#   [17] cumul_Ah
#   [18] SOH_lag_1
#   [19] QD_diff

# %%
raw = pd.read_csv(DATA_PATH)
raw = raw.drop(columns=['battery_id'], errors='ignore')
raw.head()
# Out:
#    cycle  SOC_start   SOC_end       DoD    IR_ohm     QD_Ah     QC_Ah  \
# 0      1   0.990000  0.723557  0.266443  0.079164  4.034799  3.954103
# 1      2   0.990000  0.711832  0.278168  0.037352  4.034531  3.953841
# 2      3   0.983797  0.720861  0.262936  0.049300  4.034282  3.953596
# 3      4   0.989455  0.728832  0.260623  0.036293  4.034014  3.953333
# 4      5   0.990000  0.717961  0.272039  0.050338  4.033757  3.953082
#
#    V_mean_V   V_min_V   V_max_V     Tavg_C     Tmin_C     Tmax_C  \
# 0  7.941815  7.485268  8.381634  10.052740 -10.000000  31.274196
# 1  7.949974  7.514433  8.361722  17.744833  -2.005485  31.399790
# 2  7.957037  7.488502  8.379864  15.218683  -8.895562  31.399790
# 3  7.977824  7.555081  8.381603  17.945194  -1.658271  31.340903
# 4  7.955748  7.479978  8.381609  14.989333  -9.117762  31.340903
#
#    chargetime_min  discharge_time_min       SOH  T_amb_K
# 0       54.151323           34.461756  0.999950   263.15
# 1       55.269912           35.975986  0.999884   271.15
# 2       54.581429           34.003906  0.999822   263.15
# 3       53.068946           33.702553  0.999756   271.15
# 4       55.274462           35.176602  0.999692   263.15

# %% [markdown]
# ## 4 — Chargement & tri des données

# %%
raw = raw.sort_values('cycle').reset_index(drop=True)

print(f'Shape     : {raw.shape}')
print(f'Cycles    : {raw["cycle"].min()} → {raw["cycle"].max()}')
print(f'SOH       : {raw["SOH"].min():.4f} → {raw["SOH"].max():.4f}')
raw.head()
# Out:
# Shape     : (6808, 17)
# Cycles    : 1 → 6808
# SOH       : 0.7000 → 1.0000
#    cycle  SOC_start   SOC_end       DoD    IR_ohm     QD_Ah     QC_Ah  \
# 0      1   0.990000  0.723557  0.266443  0.079164  4.034799  3.954103
# 1      2   0.990000  0.711832  0.278168  0.037352  4.034531  3.953841
# 2      3   0.983797  0.720861  0.262936  0.049300  4.034282  3.953596
# 3      4   0.989455  0.728832  0.260623  0.036293  4.034014  3.953333
# 4      5   0.990000  0.717961  0.272039  0.050338  4.033757  3.953082
#
#    V_mean_V   V_min_V   V_max_V     Tavg_C     Tmin_C     Tmax_C  \
# 0  7.941815  7.485268  8.381634  10.052740 -10.000000  31.274196
# 1  7.949974  7.514433  8.361722  17.744833  -2.005485  31.399790
# 2  7.957037  7.488502  8.379864  15.218683  -8.895562  31.399790
# 3  7.977824  7.555081  8.381603  17.945194  -1.658271  31.340903
# 4  7.955748  7.479978  8.381609  14.989333  -9.117762  31.340903
#
#    chargetime_min  discharge_time_min       SOH  T_amb_K
# 0       54.151323           34.461756  0.999950   263.15
# 1       55.269912           35.975986  0.999884   271.15
# 2       54.581429           34.003906  0.999822   263.15
# 3       53.068946           33.702553  0.999756   271.15
# 4       55.274462           35.176602  0.999692   263.15

# %% [markdown]
# ## 5 — Feature Engineering

# %%
def engineer_features(df, rolling_w=ROLLING_W):
    g = df.sort_values('cycle')

    if 'V_spread'       in FEATURE_COLS:
        df['V_spread']       = df['V_max_V'] - df['V_min_V']
    if 'V_mean_rolling' in FEATURE_COLS:
        df['V_mean_rolling'] = g['V_mean_V'].transform(
                                   lambda x: x.rolling(rolling_w, min_periods=1).mean())
    if 'V_mean_lag_1'   in FEATURE_COLS:
        df['V_mean_lag_1']   = g['V_mean_V'].transform(lambda x: x.shift(1))
    if 'V_min_fade'     in FEATURE_COLS:
        df['V_min_fade']     = g['V_min_V'].transform(lambda x: x - x.iloc[0])
    if 'thermal_range'  in FEATURE_COLS:
        df['thermal_range']    = df['Tmax_C'] - df['Tmin_C']
    if 'delta_T_ambient' in FEATURE_COLS:
        df['delta_T_ambient']  = g['T_amb_K'].transform(lambda x: x.diff())
    if 'cold_cycle_count' in FEATURE_COLS:
        df['cold_cycle_count'] = g['Tavg_C'].transform(lambda x: (x < 5).cumsum())
    if 'Tavg_rolling'   in FEATURE_COLS:
        df['Tavg_rolling']     = g['Tavg_C'].transform(
                                     lambda x: x.rolling(rolling_w, min_periods=1).mean())
    if 'eclipse_flag'   in FEATURE_COLS:
        df['eclipse_flag']     = (df['T_amb_K'] <= 263.15).astype(float)
    if 'coulombic_eff'  in FEATURE_COLS:
        df['coulombic_eff']    = df['QC_Ah'] / df['QD_Ah'].replace(0, np.nan)
    if 'discharge_C_rate' in FEATURE_COLS:
        df['discharge_C_rate'] = df['DoD'] / (df['discharge_time_min']/60).replace(0, np.nan)
    if 'capacity_retention' in FEATURE_COLS:
        df['capacity_retention'] = g['QD_Ah'].transform(lambda x: x / x.iloc[0])
    if 'QD_rolling'     in FEATURE_COLS:
        df['QD_rolling']       = g['QD_Ah'].transform(
                                     lambda x: x.rolling(rolling_w, min_periods=1).mean())
    if 'cumul_Ah'       in FEATURE_COLS:
        df['cumul_Ah']         = g['QD_Ah'].transform('cumsum')
    if 'QD_diff'        in FEATURE_COLS:
        df['QD_diff']          = g['QD_Ah'].transform(lambda x: x.diff())
    if 'SOH_lag_1'      in FEATURE_COLS:
        df['SOH_lag_1']        = g['SOH'].transform(lambda x: x.shift(1))

    return df

raw = engineer_features(raw)
raw = raw.dropna().reset_index(drop=True)
print(f'Après feature engineering : {raw.shape}')
raw[FEATURE_COLS + ['SOH']].head()
# Out:
# Après feature engineering : (6807, 33)
#    V_mean_V  V_spread  V_mean_rolling  V_mean_lag_1  V_min_fade     Tavg_C  \
# 0  7.949974  0.847289        7.945895      7.941815    0.029165  17.744833
# 1  7.957037  0.891362        7.949609      7.949974    0.003234  15.218683
# 2  7.977824  0.826522        7.956663      7.957037    0.069813  17.945194
# 3  7.955748  0.901631        7.956480      7.977824   -0.005290  14.989333
# 4  7.971622  0.838531        7.959003      7.955748    0.057793  17.936148
#
#    thermal_range  delta_T_ambient  cold_cycle_count  Tavg_rolling  ...  \
# 0      33.405275              8.0                 0     13.898787  ...
# 1      40.295351             -8.0                 0     14.338752  ...
# 2      32.999175              8.0                 0     15.240362  ...
# 3      40.458665             -8.0                 0     15.190156  ...
# 4      33.140946              8.0                 0     15.647822  ...
#
#       QD_Ah  coulombic_eff  discharge_C_rate  capacity_retention  QD_rolling  \
# 0  4.034531           0.98          0.463922            0.999934    4.034665
# 1  4.034282           0.98          0.463952            0.999872    4.034537
# 2  4.034014           0.98          0.463982            0.999805    4.034406
# 3  4.033757           0.98          0.464012            0.999742    4.034277
# 4  4.033485           0.98          0.464042            0.999674    4.034145
#
#    cycle   cumul_Ah  SOH_lag_1   QD_diff       SOH
# 0      2   8.069330   0.999950 -0.000268  0.999884
# 1      3  12.103612   0.999884 -0.000250  0.999822
# 2      4  16.137626   0.999822 -0.000268  0.999756
# 3      5  20.171383   0.999756 -0.000257  0.999692
# 4      6  24.204868   0.999692 -0.000272  0.999625
#
# [5 rows x 21 columns]

# %%
#print(raw[FEATURE_COLS + ['SOH']])

# %%
#raw[FEATURE_COLS + ['SOH']].to_csv('/content/drive/MyDrive/Colab Notebooks/outputs_1/raw_features.csv', index=False)

# %% [markdown]
# ## 6 — Vérification : toutes les features sont disponibles

# %%
missing = [f for f in FEATURE_COLS if f not in raw.columns]
if missing:
    raise ValueError(f'Features manquantes : {missing}')
print(f'✅ {len(FEATURE_COLS)}/{len(FEATURE_COLS)} features présentes.')
print()
print(raw[FEATURE_COLS].describe().T[['mean','std','min','max']].round(4).to_string())
# Out:
# ✅ 20/20 features présentes.
#
#                           mean        std      min         max
# V_mean_V                7.7045     0.1278   7.4287      7.9778
# V_spread                0.9943     0.1315   0.6769      1.3432
# V_mean_rolling          7.7047     0.1247   7.4396      7.9590
# V_mean_lag_1            7.7046     0.1279   7.4287      7.9778
# V_min_fade             -0.3113     0.1510  -0.6338      0.0698
# Tavg_C                 16.5393     1.4924  14.0529     18.9257
# thermal_range          36.6678     3.5808  32.4303     40.9656
# delta_T_ambient         0.0012     8.0006  -8.0000      8.0000
# cold_cycle_count        0.0000     0.0000   0.0000      0.0000
# Tavg_rolling           16.5375     0.1108  13.8988     16.8362
# eclipse_flag            0.4999     0.5000   0.0000      1.0000
# QD_Ah                   3.4195     0.3500   2.8244      4.0345
# coulombic_eff           0.9800     0.0000   0.9800      0.9800
# discharge_C_rate        0.5532     0.0570   0.4639      0.6627
# capacity_retention      0.8475     0.0867   0.7000      0.9999
# QD_rolling              3.4203     0.3500   2.8253      4.0347
# cycle                3405.0000  1965.1560   2.0000   6808.0000
# cumul_Ah            12331.3776  6719.2015   8.0693  23280.6700
# SOH_lag_1               0.8475     0.0867   0.7000      1.0000
# QD_diff                -0.0002     0.0000  -0.0003     -0.0001

# %% [markdown]
# ## 7 — Split chronologique (Train 80% / Val 20%)

# %%
n_total = len(raw)
n_train = int(n_total * TRAIN_FRAC)

train_df = raw.iloc[:n_train].copy()
val_df   = raw.iloc[n_train:].copy()

print(f'Train : {len(train_df):,} lignes | cycles {train_df["cycle"].min()} – {train_df["cycle"].max()}')
print(f'Val   : {len(val_df):,} lignes | cycles {val_df["cycle"].min()} – {val_df["cycle"].max()}')
print()
print(f'SOH train : {train_df["SOH"].min():.4f} → {train_df["SOH"].max():.4f}')
print(f'SOH val   : {val_df["SOH"].min():.4f} → {val_df["SOH"].max():.4f}')
print()
print('⚠ Note : le val set couvre une plage de SOH INFÉRIEURE à celle du train.')
print('  Le modèle doit extrapoler légèrement (SOH 0.78 → 0.70).')
print('  C''est normal pour un split temporel sur une dégradation monotone.')
# Out:
# Train : 5,445 lignes | cycles 2 – 5446
# Val   : 1,362 lignes | cycles 5447 – 6808
#
# SOH train : 0.7588 → 0.9999
# SOH val   : 0.7000 → 0.7587
#
# ⚠ Note : le val set couvre une plage de SOH INFÉRIEURE à celle du train.
#   Le modèle doit extrapoler légèrement (SOH 0.78 → 0.70).
#   Cest normal pour un split temporel sur une dégradation monotone.

# %% [markdown]
# ## 8 — Normalisation des features X uniquement
#
# > **Pourquoi on ne normalise PAS la cible SOH ici :**
# >
# > `MinMaxScaler` fitté sur le train (SOH ∈ [0.78, 1.0]) map le val set
# > (SOH ∈ [0.70, 0.78]) vers des valeurs **négatives** ([−0.36, 0]).
# > La sortie `sigmoid` étant bornée à [0, 1], le modèle clique toutes les
# > prédictions à ≈ 0 dès le départ et ne reçoit aucun gradient utile.
# >
# > **Solution** : SOH est déjà borné dans [0, 1] par définition physique.
# > On l'utilise brut comme cible. `sigmoid` en sortie reste cohérent.

# %%
# Features X — fit sur train uniquement, transform sur val
scaler_X = StandardScaler()
train_df[FEATURE_COLS] = scaler_X.fit_transform(train_df[FEATURE_COLS])
val_df  [FEATURE_COLS] = scaler_X.transform(val_df[FEATURE_COLS])


# SOH ∈ [0.70, 1.00] → déjà dans [0, 1], aucune normalisation nécessaire
print('scaler_X fitté sur train uniquement ✅')
print(f'SOH train (cible) : {train_df["SOH"].min():.4f} → {train_df["SOH"].max():.4f}')
print(f'SOH val   (cible) : {val_df["SOH"].min():.4f} → {val_df["SOH"].max():.4f}')
print('Aucun scaler_y — SOH utilisé directement ✅')
# Out:
# scaler_X fitté sur train uniquement ✅
# SOH train (cible) : 0.7588 → 0.9999
# SOH val   (cible) : 0.7000 → 0.7587
# Aucun scaler_y — SOH utilisé directement ✅

# %% [markdown]
# ## 9 — Construction des séquences
#
# - **X** : fenêtre de `WINDOW_SIZE` cycles de features normalisées
# - **y** : SOH brut au cycle `t + HORIZON` (cible directe)

# %%
print(f'WINDOW={WINDOW_SIZE}  STEP={STEP_SIZE}  HORIZON={HORIZON}  Features={len(FEATURE_COLS)}')

def build_sequences(df, window, step, horizon):
    features = df[FEATURE_COLS].values.astype(np.float32)
    soh_raw  = df['SOH'].values.astype(np.float32)   # cible brute ∈ [0,1]

    n         = len(df)
    max_start = n - window - horizon + 1
    if max_start <= 0:
        raise ValueError(f'Données insuffisantes ({n}) pour window={window}+horizon={horizon}')

    X_list, y_list = [], []
    for start in range(0, max_start, step):
        end  = start + window
        pred = end   + horizon - 1
        X_list.append(features[start:end])
        y_list.append(soh_raw[pred])

    X = np.array(X_list, dtype=np.float32)
    y = np.array(y_list, dtype=np.float32)
    print(f'  {n:,} lignes → {len(X):,} séquences | X={X.shape}  y={y.shape}')
    print(f'  y min={y.min():.4f}  max={y.max():.4f}')
    return X, y

print('[Train]')
X_train, y_train = build_sequences(train_df, WINDOW_SIZE, STEP_SIZE, HORIZON)
print('[Val]')
X_val,   y_val   = build_sequences(val_df,   WINDOW_SIZE, STEP_SIZE, HORIZON)

for arr, name in [(X_train,'X_train'),(X_val,'X_val'),(y_train,'y_train'),(y_val,'y_val')]:
    assert not np.any(np.isnan(arr)), f'NaN dans {name}!'
print('✅ Aucun NaN')
# Out:
# WINDOW=30  STEP=3  HORIZON=1  Features=20
# [Train]
#   5,445 lignes → 1,805 séquences | X=(1805, 30, 20)  y=(1805,)
#   y min=0.7589  max=0.9981
# [Val]
#   1,362 lignes → 444 séquences | X=(444, 30, 20)  y=(444,)
#   y min=0.7001  max=0.7576
# ✅ Aucun NaN

# %%
import tensorflow as tf
import keras
from keras import layers

@keras.saving.register_keras_serializable(package="cubesat_soh")
class AttentionContext(layers.Layer):
    def call(self, inputs):
        return tf.reduce_sum(inputs, axis=1)

    def compute_output_shape(self, input_shape):
        return (input_shape[0], input_shape[2])

# %% [markdown]
# ## 10 — Architecture LSTM
#
# Sortie : **`sigmoid`** — borne la prédiction dans [0, 1], cohérent avec SOH brut.
# Dropout → BatchNorm dans chaque bloc.

# %%
def build_model_v3(window_size, n_features, lr=3e-4, l2_reg=2e-4, seed=42):
    """
    LSTM v3 for CubeSat SOH regression — optimized for STM32F401RE
    (94 KB RAM / 512 KB flash).

    Changes vs v2, and why they don't cost accuracy:
      - LSTM 128 -> 64, LSTM 64 -> 32
        20 input features over a 30-step window is a small,
        low-dimensional signal (voltage/temp/capacity stats).
        128+64 units was sized for a much richer input; 64+32
        keeps the same 2-layer temporal structure with plenty
        of margin for a monotonic degradation curve like SOH fade.
      - MultiHeadAttention -> additive (Bahdanau) attention pooling
        Same *purpose* (learn which cycles in the window matter most:
        a voltage dip, a temperature spike, the fade inflection point)
        but instead of 4 learned 64x64 projection matrices (Q/K/V/O),
        it's 2 small Dense layers that score each timestep and a
        softmax-weighted sum. This also replaces GlobalAveragePooling1D
        entirely -- attention pooling already collapses the timestep axis.
      - Dense head 64 -> 24
        Scaled down to match the smaller upstream representation.

    Architecture flow:
        Input (window_size, n_features)
            |
            v
        LSTM 64  return_sequences=True
        LayerNorm + Dropout 0.2
            |
            v
        LSTM 32  return_sequences=True
        LayerNorm + Dropout 0.2
            |
            v
        Additive attention pooling  (Dense(16,tanh) -> Dense(1) -> softmax -> weighted sum)
        -> context vector (batch, 32)
            |
            v
        Dense 24  activation=ELU
        Dropout 0.1
            |
            v
        Dense 1   activation=sigmoid
    """
    inputs = tf.keras.Input(shape=(window_size, n_features), name='input')

    # -- LSTM block 1 --------------------------------------------------
    x = LSTM(
        64,
        return_sequences=True,
        unroll=True,
        kernel_regularizer=l2(l2_reg),
        name='lstm_1',
    )(inputs)
    x = LayerNormalization(name='ln_1')(x)
    x = Dropout(0.2, seed=seed, name='drop_1')(x)

    # -- LSTM block 2 --------------------------------------------------
    x = LSTM(
        32,
        return_sequences=True,
        kernel_regularizer=l2(l2_reg),
        unroll=True,
        name='lstm_2',
    )(x)
    x = LayerNormalization(name='ln_2')(x)
    x = Dropout(0.2, seed=seed + 1, name='drop_2')(x)

    # -- Additive (Bahdanau-style) attention pooling --------------------
    # Scores each of the 30 timesteps with a small MLP, normalizes the
    # scores with softmax across the time axis, then takes the weighted
    # sum -- same "attend to the important cycles" idea as
    # MultiHeadAttention, at a fraction of the parameter cost.
    attn_hidden = Dense(16, activation='tanh', name='attn_hidden')(x)      # (batch, T, 16)
    attn_scores = Dense(1, name='attn_score')(attn_hidden)                  # (batch, T, 1)
    attn_weights = tf.keras.layers.Softmax(axis=1, name='attn_softmax')(attn_scores)  # (batch, T, 1)
    weighted = tf.keras.layers.Multiply(name='attn_weighted')([x, attn_weights])       # (batch, T, 32)
    context = AttentionContext(name='attn_context')(weighted)                                                            # (batch, 32)

    # -- Dense head ------------------------------------------------------
    x = Dense(
        24,
        activation='elu',
        kernel_regularizer=l2(l2_reg),
        name='dense_1',
    )(context)
    x = Dropout(0.1, seed=seed + 2, name='drop_3')(x)

    # -- Output ------------------------------------------------------
    output = Dense(1, activation='sigmoid', name='SOH_output')(x)

    model = tf.keras.Model(inputs, output, name='LSTM_SOH_v3')

    model.compile(
       optimizer=tf.keras.optimizers.AdamW(
           learning_rate=lr,
           weight_decay=l2_reg,
           clipnorm=1.0,
       ),
        loss=tf.keras.losses.Huber(delta=0.01),
        metrics=['mae'],
    )
    return model


# Build and inspect
model = build_model_v3(WINDOW_SIZE, X_train.shape[2])
model.summary()

total_params = model.count_params()
print(f'\nTotal parameters : {total_params:,}')
print(f'fp32 size        : {total_params*4/1024:.1f} KB')
print(f'int8 size (est.) : {total_params*1/1024:.1f} KB  (after post-training quantization)')
# Out:
# Model: "LSTM_SOH_v3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 30, 20)    │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ (None, 30, 64)    │     21,760 │ input[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_1                │ (None, 30, 64)    │        128 │ lstm_1[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ drop_1 (Dropout)    │ (None, 30, 64)    │          0 │ ln_1[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ (None, 30, 32)    │     12,416 │ drop_1[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_2                │ (None, 30, 32)    │         64 │ lstm_2[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ drop_2 (Dropout)    │ (None, 30, 32)    │          0 │ ln_2[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn_hidden (Dense) │ (None, 30, 16)    │        528 │ drop_2[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn_score (Dense)  │ (None, 30, 1)     │         17 │ attn_hidden[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn_softmax        │ (None, 30, 1)     │          0 │ attn_score[0][0]  │
# │ (Softmax)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn_weighted       │ (None, 30, 32)    │          0 │ drop_2[0][0],     │
# │ (Multiply)          │                   │            │ attn_softmax[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn_context        │ (None, 32)        │          0 │ attn_weighted[0]… │
# │ (AttentionContext)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 24)        │        792 │ attn_context[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ drop_3 (Dropout)    │ (None, 24)        │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ SOH_output (Dense)  │ (None, 1)         │         25 │ drop_3[0][0]      │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 35,730 (139.57 KB)
#  Trainable params: 35,730 (139.57 KB)
#  Non-trainable params: 0 (0.00 B)
# Total parameters : 35,730
# fp32 size        : 139.6 KB
# int8 size (est.) : 34.9 KB  (after post-training quantization)

# %% [markdown]
# ## 11 — Entraînement

# %%
callbacks = [
    EarlyStopping(monitor='val_loss', patience=25,
                  restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss',
                      factor=0.3,    # ← plus agressif (était 0.5)
                      patience=5,    # ← plus réactif (était 8)
                      min_lr=1e-6, verbose=1),
]

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=MAX_EPOCHS,
    batch_size=128,   # ← garder 128
    callbacks=callbacks,
    shuffle=True,
    verbose=1,
)
print('\n✅ Entraînement terminé')
# Out:
# Epoch 1/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 16s 127ms/step - loss: 0.0315 - mae: 0.2358 - val_loss: 0.0291 - val_mae: 0.0717 - learning_rate: 3.0000e-04
# Epoch 2/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0282 - mae: 0.0482 - val_loss: 0.0272 - val_mae: 0.0396 - learning_rate: 3.0000e-04
# Epoch 3/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0265 - mae: 0.0346 - val_loss: 0.0255 - val_mae: 0.0305 - learning_rate: 3.0000e-04
# Epoch 4/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0249 - mae: 0.0340 - val_loss: 0.0240 - val_mae: 0.0279 - learning_rate: 3.0000e-04
# Epoch 5/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0234 - mae: 0.0315 - val_loss: 0.0224 - val_mae: 0.0179 - learning_rate: 3.0000e-04
# Epoch 6/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0219 - mae: 0.0300 - val_loss: 0.0210 - val_mae: 0.0180 - learning_rate: 3.0000e-04
# Epoch 7/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0206 - mae: 0.0305 - val_loss: 0.0197 - val_mae: 0.0134 - learning_rate: 3.0000e-04
# Epoch 8/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0193 - mae: 0.0282 - val_loss: 0.0184 - val_mae: 0.0092 - learning_rate: 3.0000e-04
# Epoch 9/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0180 - mae: 0.0273 - val_loss: 0.0173 - val_mae: 0.0191 - learning_rate: 3.0000e-04
# Epoch 10/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0169 - mae: 0.0264 - val_loss: 0.0162 - val_mae: 0.0157 - learning_rate: 3.0000e-04
# Epoch 11/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0158 - mae: 0.0263 - val_loss: 0.0151 - val_mae: 0.0081 - learning_rate: 3.0000e-04
# Epoch 12/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0148 - mae: 0.0256 - val_loss: 0.0141 - val_mae: 0.0087 - learning_rate: 3.0000e-04
# Epoch 13/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0139 - mae: 0.0248 - val_loss: 0.0132 - val_mae: 0.0079 - learning_rate: 3.0000e-04
# Epoch 14/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0130 - mae: 0.0236 - val_loss: 0.0124 - val_mae: 0.0090 - learning_rate: 3.0000e-04
# Epoch 15/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0121 - mae: 0.0228 - val_loss: 0.0117 - val_mae: 0.0199 - learning_rate: 3.0000e-04
# Epoch 16/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0114 - mae: 0.0228 - val_loss: 0.0109 - val_mae: 0.0134 - learning_rate: 3.0000e-04
# Epoch 17/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0106 - mae: 0.0227 - val_loss: 0.0102 - val_mae: 0.0125 - learning_rate: 3.0000e-04
# Epoch 18/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0100 - mae: 0.0223 - val_loss: 0.0096 - val_mae: 0.0187 - learning_rate: 3.0000e-04
# Epoch 19/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0093 - mae: 0.0216 - val_loss: 0.0089 - val_mae: 0.0137 - learning_rate: 3.0000e-04
# Epoch 20/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0087 - mae: 0.0215 - val_loss: 0.0085 - val_mae: 0.0334 - learning_rate: 3.0000e-04
# Epoch 21/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0082 - mae: 0.0207 - val_loss: 0.0078 - val_mae: 0.0111 - learning_rate: 3.0000e-04
# Epoch 22/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0076 - mae: 0.0201 - val_loss: 0.0072 - val_mae: 0.0048 - learning_rate: 3.0000e-04
# Epoch 23/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0072 - mae: 0.0196 - val_loss: 0.0068 - val_mae: 0.0041 - learning_rate: 3.0000e-04
# Epoch 24/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0067 - mae: 0.0194 - val_loss: 0.0064 - val_mae: 0.0144 - learning_rate: 3.0000e-04
# Epoch 25/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0063 - mae: 0.0200 - val_loss: 0.0059 - val_mae: 0.0068 - learning_rate: 3.0000e-04
# Epoch 26/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0059 - mae: 0.0189 - val_loss: 0.0056 - val_mae: 0.0095 - learning_rate: 3.0000e-04
# Epoch 27/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0055 - mae: 0.0187 - val_loss: 0.0053 - val_mae: 0.0173 - learning_rate: 3.0000e-04
# Epoch 28/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0052 - mae: 0.0177 - val_loss: 0.0049 - val_mae: 0.0127 - learning_rate: 3.0000e-04
# Epoch 29/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0049 - mae: 0.0185 - val_loss: 0.0046 - val_mae: 0.0046 - learning_rate: 3.0000e-04
# Epoch 30/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0045 - mae: 0.0179 - val_loss: 0.0043 - val_mae: 0.0039 - learning_rate: 3.0000e-04
# Epoch 31/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0043 - mae: 0.0183 - val_loss: 0.0040 - val_mae: 0.0038 - learning_rate: 3.0000e-04
# Epoch 32/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0040 - mae: 0.0178 - val_loss: 0.0037 - val_mae: 0.0043 - learning_rate: 3.0000e-04
# Epoch 33/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0038 - mae: 0.0176 - val_loss: 0.0036 - val_mae: 0.0105 - learning_rate: 3.0000e-04
# Epoch 34/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0035 - mae: 0.0180 - val_loss: 0.0033 - val_mae: 0.0108 - learning_rate: 3.0000e-04
# Epoch 35/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0033 - mae: 0.0177 - val_loss: 0.0031 - val_mae: 0.0045 - learning_rate: 3.0000e-04
# Epoch 36/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0031 - mae: 0.0172 - val_loss: 0.0029 - val_mae: 0.0055 - learning_rate: 3.0000e-04
# Epoch 37/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0030 - mae: 0.0176 - val_loss: 0.0028 - val_mae: 0.0082 - learning_rate: 3.0000e-04
# Epoch 38/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0028 - mae: 0.0173 - val_loss: 0.0027 - val_mae: 0.0162 - learning_rate: 3.0000e-04
# Epoch 39/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0026 - mae: 0.0174 - val_loss: 0.0026 - val_mae: 0.0203 - learning_rate: 3.0000e-04
# Epoch 40/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0025 - mae: 0.0166 - val_loss: 0.0024 - val_mae: 0.0215 - learning_rate: 3.0000e-04
# Epoch 41/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0023 - mae: 0.0173 - val_loss: 0.0023 - val_mae: 0.0221 - learning_rate: 3.0000e-04
# Epoch 42/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0022 - mae: 0.0185 - val_loss: 0.0021 - val_mae: 0.0139 - learning_rate: 3.0000e-04
# Epoch 43/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0021 - mae: 0.0162 - val_loss: 0.0019 - val_mae: 0.0065 - learning_rate: 3.0000e-04
# Epoch 44/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0020 - mae: 0.0162 - val_loss: 0.0018 - val_mae: 0.0023 - learning_rate: 3.0000e-04
# Epoch 45/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0019 - mae: 0.0164 - val_loss: 0.0017 - val_mae: 0.0047 - learning_rate: 3.0000e-04
# Epoch 46/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0018 - mae: 0.0158 - val_loss: 0.0016 - val_mae: 0.0053 - learning_rate: 3.0000e-04
# Epoch 47/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0017 - mae: 0.0159 - val_loss: 0.0016 - val_mae: 0.0097 - learning_rate: 3.0000e-04
# Epoch 48/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0016 - mae: 0.0152 - val_loss: 0.0015 - val_mae: 0.0127 - learning_rate: 3.0000e-04
# Epoch 49/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0015 - mae: 0.0160 - val_loss: 0.0013 - val_mae: 0.0034 - learning_rate: 3.0000e-04
# Epoch 50/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0014 - mae: 0.0153 - val_loss: 0.0013 - val_mae: 0.0026 - learning_rate: 3.0000e-04
# Epoch 51/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0013 - mae: 0.0153 - val_loss: 0.0012 - val_mae: 0.0082 - learning_rate: 3.0000e-04
# Epoch 52/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 131ms/step - loss: 0.0013 - mae: 0.0153 - val_loss: 0.0012 - val_mae: 0.0080 - learning_rate: 3.0000e-04
# Epoch 53/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 0.0012 - mae: 0.0154 - val_loss: 0.0011 - val_mae: 0.0033 - learning_rate: 3.0000e-04
# Epoch 54/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0012 - mae: 0.0149 - val_loss: 0.0010 - val_mae: 0.0043 - learning_rate: 3.0000e-04
# Epoch 55/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0011 - mae: 0.0148 - val_loss: 9.6545e-04 - val_mae: 0.0011 - learning_rate: 3.0000e-04
# Epoch 56/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0010 - mae: 0.0144 - val_loss: 9.3622e-04 - val_mae: 0.0060 - learning_rate: 3.0000e-04
# Epoch 57/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 9.9733e-04 - mae: 0.0147 - val_loss: 8.7670e-04 - val_mae: 0.0041 - learning_rate: 3.0000e-04
# Epoch 58/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 9.5002e-04 - mae: 0.0146 - val_loss: 8.3095e-04 - val_mae: 0.0033 - learning_rate: 3.0000e-04
# Epoch 59/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 9.0246e-04 - mae: 0.0142 - val_loss: 8.8140e-04 - val_mae: 0.0151 - learning_rate: 3.0000e-04
# Epoch 60/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 8.6261e-04 - mae: 0.0143 - val_loss: 7.6061e-04 - val_mae: 0.0057 - learning_rate: 3.0000e-04
# Epoch 61/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 8.2294e-04 - mae: 0.0142 - val_loss: 7.3233e-04 - val_mae: 0.0074 - learning_rate: 3.0000e-04
# Epoch 62/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 7.8817e-04 - mae: 0.0144 - val_loss: 6.7236e-04 - val_mae: 0.0025 - learning_rate: 3.0000e-04
# Epoch 63/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 7.5114e-04 - mae: 0.0140 - val_loss: 6.3713e-04 - val_mae: 0.0021 - learning_rate: 3.0000e-04
# Epoch 64/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 7.1834e-04 - mae: 0.0140 - val_loss: 6.0772e-04 - val_mae: 0.0025 - learning_rate: 3.0000e-04
# Epoch 65/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 6.8821e-04 - mae: 0.0141 - val_loss: 6.7809e-04 - val_mae: 0.0154 - learning_rate: 3.0000e-04
# Epoch 66/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 6.5426e-04 - mae: 0.0135 - val_loss: 5.7771e-04 - val_mae: 0.0079 - learning_rate: 3.0000e-04
# Epoch 67/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 6.2571e-04 - mae: 0.0134 - val_loss: 5.2784e-04 - val_mae: 0.0041 - learning_rate: 3.0000e-04
# Epoch 68/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 6.0028e-04 - mae: 0.0135 - val_loss: 5.6183e-04 - val_mae: 0.0118 - learning_rate: 3.0000e-04
# Epoch 69/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 5.7291e-04 - mae: 0.0132 - val_loss: 5.7177e-04 - val_mae: 0.0152 - learning_rate: 3.0000e-04
# Epoch 70/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 5.5559e-04 - mae: 0.0138 - val_loss: 4.5695e-04 - val_mae: 0.0034 - learning_rate: 3.0000e-04
# Epoch 71/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 5.3091e-04 - mae: 0.0134 - val_loss: 4.2914e-04 - val_mae: 0.0018 - learning_rate: 3.0000e-04
# Epoch 72/400
# 14/15 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 5.1356e-04 - mae: 0.0134
# Epoch 72: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 5.1010e-04 - mae: 0.0135 - val_loss: 4.2839e-04 - val_mae: 0.0063 - learning_rate: 3.0000e-04
# Epoch 73/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 4.9301e-04 - mae: 0.0132 - val_loss: 4.0260e-04 - val_mae: 0.0019 - learning_rate: 9.0000e-05
# Epoch 74/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 4.8426e-04 - mae: 0.0128 - val_loss: 4.1570e-04 - val_mae: 0.0061 - learning_rate: 9.0000e-05
# Epoch 75/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.7804e-04 - mae: 0.0128 - val_loss: 3.9816e-04 - val_mae: 0.0039 - learning_rate: 9.0000e-05
# Epoch 76/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 4.7308e-04 - mae: 0.0129 - val_loss: 4.1425e-04 - val_mae: 0.0076 - learning_rate: 9.0000e-05
# Epoch 77/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.6489e-04 - mae: 0.0126 - val_loss: 3.8610e-04 - val_mae: 0.0036 - learning_rate: 9.0000e-05
# Epoch 78/400
# 14/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.5946e-04 - mae: 0.0125
# Epoch 78: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 4.6295e-04 - mae: 0.0130 - val_loss: 3.8277e-04 - val_mae: 0.0042 - learning_rate: 9.0000e-05
# Epoch 79/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.5599e-04 - mae: 0.0126 - val_loss: 3.7944e-04 - val_mae: 0.0037 - learning_rate: 2.7000e-05
# Epoch 80/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 4.5732e-04 - mae: 0.0129 - val_loss: 3.8759e-04 - val_mae: 0.0058 - learning_rate: 2.7000e-05
# Epoch 81/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.5079e-04 - mae: 0.0124 - val_loss: 3.7055e-04 - val_mae: 0.0020 - learning_rate: 2.7000e-05
# Epoch 82/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.5166e-04 - mae: 0.0127 - val_loss: 3.6803e-04 - val_mae: 0.0017 - learning_rate: 2.7000e-05
# Epoch 83/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.5284e-04 - mae: 0.0129
# Epoch 83: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.5417e-04 - mae: 0.0131 - val_loss: 3.6693e-04 - val_mae: 0.0019 - learning_rate: 2.7000e-05
# Epoch 84/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 4.4852e-04 - mae: 0.0126 - val_loss: 3.6574e-04 - val_mae: 0.0018 - learning_rate: 8.1000e-06
# Epoch 85/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.5248e-04 - mae: 0.0131 - val_loss: 3.6554e-04 - val_mae: 0.0018 - learning_rate: 8.1000e-06
# Epoch 86/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 4.4879e-04 - mae: 0.0128 - val_loss: 3.6391e-04 - val_mae: 0.0013 - learning_rate: 8.1000e-06
# Epoch 87/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.4379e-04 - mae: 0.0123 - val_loss: 3.6307e-04 - val_mae: 0.0012 - learning_rate: 8.1000e-06
# Epoch 88/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.4749e-04 - mae: 0.0127
# Epoch 88: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.4879e-04 - mae: 0.0129 - val_loss: 3.6747e-04 - val_mae: 0.0031 - learning_rate: 8.1000e-06
# Epoch 89/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.4515e-04 - mae: 0.0125 - val_loss: 3.6631e-04 - val_mae: 0.0027 - learning_rate: 2.4300e-06
# Epoch 90/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.4937e-04 - mae: 0.0130 - val_loss: 3.6400e-04 - val_mae: 0.0020 - learning_rate: 2.4300e-06
# Epoch 91/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.4486e-04 - mae: 0.0125 - val_loss: 3.6410e-04 - val_mae: 0.0021 - learning_rate: 2.4300e-06
# Epoch 92/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.4553e-04 - mae: 0.0126 - val_loss: 3.6359e-04 - val_mae: 0.0019 - learning_rate: 2.4300e-06
# Epoch 93/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.4544e-04 - mae: 0.0126
# Epoch 93: ReduceLROnPlateau reducing learning rate to 1e-06.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.4541e-04 - mae: 0.0126 - val_loss: 3.6249e-04 - val_mae: 0.0015 - learning_rate: 2.4300e-06
# Epoch 94/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.4741e-04 - mae: 0.0129 - val_loss: 3.6256e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 95/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.4606e-04 - mae: 0.0127 - val_loss: 3.6272e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 96/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.4730e-04 - mae: 0.0129 - val_loss: 3.6277e-04 - val_mae: 0.0017 - learning_rate: 1.0000e-06
# Epoch 97/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 4.4564e-04 - mae: 0.0127 - val_loss: 3.6269e-04 - val_mae: 0.0017 - learning_rate: 1.0000e-06
# Epoch 98/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 4.4460e-04 - mae: 0.0126 - val_loss: 3.6239e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 99/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.4754e-04 - mae: 0.0129 - val_loss: 3.6188e-04 - val_mae: 0.0014 - learning_rate: 1.0000e-06
# Epoch 100/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.4269e-04 - mae: 0.0124 - val_loss: 3.6212e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 101/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.4563e-04 - mae: 0.0127 - val_loss: 3.6216e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 102/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.4920e-04 - mae: 0.0131 - val_loss: 3.6188e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 103/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.4762e-04 - mae: 0.0130 - val_loss: 3.6226e-04 - val_mae: 0.0017 - learning_rate: 1.0000e-06
# Epoch 104/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.4565e-04 - mae: 0.0127 - val_loss: 3.6221e-04 - val_mae: 0.0017 - learning_rate: 1.0000e-06
# Epoch 105/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.4198e-04 - mae: 0.0124 - val_loss: 3.6200e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 106/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.4506e-04 - mae: 0.0127 - val_loss: 3.6246e-04 - val_mae: 0.0019 - learning_rate: 1.0000e-06
# Epoch 107/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.4450e-04 - mae: 0.0127 - val_loss: 3.6209e-04 - val_mae: 0.0017 - learning_rate: 1.0000e-06
# Epoch 108/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.4163e-04 - mae: 0.0123 - val_loss: 3.6144e-04 - val_mae: 0.0014 - learning_rate: 1.0000e-06
# Epoch 109/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.4232e-04 - mae: 0.0124 - val_loss: 3.6123e-04 - val_mae: 0.0014 - learning_rate: 1.0000e-06
# Epoch 110/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.4517e-04 - mae: 0.0128 - val_loss: 3.6144e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 111/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.4537e-04 - mae: 0.0128 - val_loss: 3.6114e-04 - val_mae: 0.0014 - learning_rate: 1.0000e-06
# Epoch 112/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.4084e-04 - mae: 0.0123 - val_loss: 3.6097e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 113/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 4.4394e-04 - mae: 0.0126 - val_loss: 3.6113e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 114/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.4497e-04 - mae: 0.0128 - val_loss: 3.6110e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 115/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.4078e-04 - mae: 0.0123 - val_loss: 3.6129e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 116/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.4446e-04 - mae: 0.0127 - val_loss: 3.6222e-04 - val_mae: 0.0021 - learning_rate: 1.0000e-06
# Epoch 117/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.4450e-04 - mae: 0.0128 - val_loss: 3.6197e-04 - val_mae: 0.0020 - learning_rate: 1.0000e-06
# Epoch 118/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 4.4435e-04 - mae: 0.0127 - val_loss: 3.6105e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 119/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 4.4668e-04 - mae: 0.0129 - val_loss: 3.6032e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 120/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 4.4534e-04 - mae: 0.0129 - val_loss: 3.6037e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 121/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.4432e-04 - mae: 0.0128 - val_loss: 3.6065e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 122/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.4099e-04 - mae: 0.0124 - val_loss: 3.6075e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 123/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 4.4472e-04 - mae: 0.0128 - val_loss: 3.6056e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 124/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.4370e-04 - mae: 0.0127 - val_loss: 3.6078e-04 - val_mae: 0.0017 - learning_rate: 1.0000e-06
# Epoch 125/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.4255e-04 - mae: 0.0125 - val_loss: 3.6119e-04 - val_mae: 0.0019 - learning_rate: 1.0000e-06
# Epoch 126/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.4457e-04 - mae: 0.0128 - val_loss: 3.6185e-04 - val_mae: 0.0022 - learning_rate: 1.0000e-06
# Epoch 127/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.4259e-04 - mae: 0.0126 - val_loss: 3.6091e-04 - val_mae: 0.0019 - learning_rate: 1.0000e-06
# Epoch 128/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.4371e-04 - mae: 0.0127 - val_loss: 3.6039e-04 - val_mae: 0.0017 - learning_rate: 1.0000e-06
# Epoch 129/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 4.4264e-04 - mae: 0.0126 - val_loss: 3.6025e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 130/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.3776e-04 - mae: 0.0121 - val_loss: 3.6007e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 131/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.4437e-04 - mae: 0.0128 - val_loss: 3.6014e-04 - val_mae: 0.0017 - learning_rate: 1.0000e-06
# Epoch 132/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.4577e-04 - mae: 0.0130 - val_loss: 3.5979e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 133/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.4506e-04 - mae: 0.0129 - val_loss: 3.5974e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 134/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.4494e-04 - mae: 0.0129 - val_loss: 3.5976e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 135/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 4.3952e-04 - mae: 0.0124 - val_loss: 3.5906e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 136/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 4.4086e-04 - mae: 0.0125 - val_loss: 3.5892e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 137/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.4397e-04 - mae: 0.0128 - val_loss: 3.5886e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 138/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 4.4011e-04 - mae: 0.0124 - val_loss: 3.5871e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 139/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 4.3806e-04 - mae: 0.0122 - val_loss: 3.5867e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 140/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.4418e-04 - mae: 0.0129 - val_loss: 3.5842e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 141/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 4.3912e-04 - mae: 0.0123 - val_loss: 3.5857e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 142/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.4139e-04 - mae: 0.0126 - val_loss: 3.5858e-04 - val_mae: 0.0014 - learning_rate: 1.0000e-06
# Epoch 143/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.4297e-04 - mae: 0.0128 - val_loss: 3.5855e-04 - val_mae: 0.0014 - learning_rate: 1.0000e-06
# Epoch 144/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.4512e-04 - mae: 0.0130 - val_loss: 3.5854e-04 - val_mae: 0.0014 - learning_rate: 1.0000e-06
# Epoch 145/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.4241e-04 - mae: 0.0127 - val_loss: 3.5855e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 146/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.4165e-04 - mae: 0.0127 - val_loss: 3.5859e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 147/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 4.4347e-04 - mae: 0.0128 - val_loss: 3.5842e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 148/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.4078e-04 - mae: 0.0126 - val_loss: 3.5868e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 149/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.4351e-04 - mae: 0.0129 - val_loss: 3.5867e-04 - val_mae: 0.0017 - learning_rate: 1.0000e-06
# Epoch 150/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.4052e-04 - mae: 0.0126 - val_loss: 3.5907e-04 - val_mae: 0.0019 - learning_rate: 1.0000e-06
# Epoch 151/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.4158e-04 - mae: 0.0127 - val_loss: 3.5812e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 152/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.4015e-04 - mae: 0.0126 - val_loss: 3.5796e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 153/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.3702e-04 - mae: 0.0122 - val_loss: 3.5769e-04 - val_mae: 0.0014 - learning_rate: 1.0000e-06
# Epoch 154/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.4053e-04 - mae: 0.0126 - val_loss: 3.5754e-04 - val_mae: 0.0014 - learning_rate: 1.0000e-06
# Epoch 155/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.4469e-04 - mae: 0.0130 - val_loss: 3.5734e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 156/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.4096e-04 - mae: 0.0127 - val_loss: 3.5742e-04 - val_mae: 0.0014 - learning_rate: 1.0000e-06
# Epoch 157/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.4169e-04 - mae: 0.0128 - val_loss: 3.5710e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 158/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.4084e-04 - mae: 0.0127 - val_loss: 3.5707e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 159/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 4.4423e-04 - mae: 0.0130 - val_loss: 3.5730e-04 - val_mae: 0.0014 - learning_rate: 1.0000e-06
# Epoch 160/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 4.4235e-04 - mae: 0.0129 - val_loss: 3.5750e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 161/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 4.4119e-04 - mae: 0.0128 - val_loss: 3.5737e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 162/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 4.4390e-04 - mae: 0.0130 - val_loss: 3.5696e-04 - val_mae: 0.0014 - learning_rate: 1.0000e-06
# Epoch 163/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 4.3956e-04 - mae: 0.0126 - val_loss: 3.5688e-04 - val_mae: 0.0014 - learning_rate: 1.0000e-06
# Epoch 164/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.3963e-04 - mae: 0.0126 - val_loss: 3.5715e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 165/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.4205e-04 - mae: 0.0129 - val_loss: 3.5708e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 166/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.3723e-04 - mae: 0.0124 - val_loss: 3.5714e-04 - val_mae: 0.0017 - learning_rate: 1.0000e-06
# Epoch 167/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.4010e-04 - mae: 0.0127 - val_loss: 3.5662e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 168/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.3706e-04 - mae: 0.0124 - val_loss: 3.5662e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 169/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.4004e-04 - mae: 0.0127 - val_loss: 3.5733e-04 - val_mae: 0.0019 - learning_rate: 1.0000e-06
# Epoch 170/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.3967e-04 - mae: 0.0127 - val_loss: 3.5811e-04 - val_mae: 0.0022 - learning_rate: 1.0000e-06
# Epoch 171/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.3597e-04 - mae: 0.0123 - val_loss: 3.5766e-04 - val_mae: 0.0021 - learning_rate: 1.0000e-06
# Epoch 172/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.4058e-04 - mae: 0.0128 - val_loss: 3.5715e-04 - val_mae: 0.0019 - learning_rate: 1.0000e-06
# Epoch 173/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.3932e-04 - mae: 0.0127 - val_loss: 3.5686e-04 - val_mae: 0.0018 - learning_rate: 1.0000e-06
# Epoch 174/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.4223e-04 - mae: 0.0130 - val_loss: 3.5663e-04 - val_mae: 0.0018 - learning_rate: 1.0000e-06
# Epoch 175/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.4071e-04 - mae: 0.0129 - val_loss: 3.5583e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 176/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.3955e-04 - mae: 0.0127 - val_loss: 3.5528e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 177/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.3779e-04 - mae: 0.0126 - val_loss: 3.5504e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 178/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.3761e-04 - mae: 0.0125 - val_loss: 3.5490e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 179/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.3641e-04 - mae: 0.0124 - val_loss: 3.5492e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 180/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.4130e-04 - mae: 0.0130 - val_loss: 3.5557e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 181/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 4.3727e-04 - mae: 0.0125 - val_loss: 3.5532e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 182/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 4.3839e-04 - mae: 0.0127 - val_loss: 3.5523e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 183/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 4.4260e-04 - mae: 0.0131 - val_loss: 3.5571e-04 - val_mae: 0.0017 - learning_rate: 1.0000e-06
# Epoch 184/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 4.3673e-04 - mae: 0.0124 - val_loss: 3.5493e-04 - val_mae: 0.0014 - learning_rate: 1.0000e-06
# Epoch 185/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.3792e-04 - mae: 0.0127 - val_loss: 3.5452e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 186/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.3899e-04 - mae: 0.0128 - val_loss: 3.5444e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 187/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.3118e-04 - mae: 0.0119 - val_loss: 3.5456e-04 - val_mae: 0.0014 - learning_rate: 1.0000e-06
# Epoch 188/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.3556e-04 - mae: 0.0124 - val_loss: 3.5516e-04 - val_mae: 0.0017 - learning_rate: 1.0000e-06
# Epoch 189/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.3829e-04 - mae: 0.0127 - val_loss: 3.5527e-04 - val_mae: 0.0018 - learning_rate: 1.0000e-06
# Epoch 190/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.3524e-04 - mae: 0.0124 - val_loss: 3.5450e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 191/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.3888e-04 - mae: 0.0129 - val_loss: 3.5490e-04 - val_mae: 0.0018 - learning_rate: 1.0000e-06
# Epoch 192/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.3926e-04 - mae: 0.0129 - val_loss: 3.5539e-04 - val_mae: 0.0020 - learning_rate: 1.0000e-06
# Epoch 193/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.3782e-04 - mae: 0.0127 - val_loss: 3.5611e-04 - val_mae: 0.0023 - learning_rate: 1.0000e-06
# Epoch 194/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.3682e-04 - mae: 0.0126 - val_loss: 3.5535e-04 - val_mae: 0.0021 - learning_rate: 1.0000e-06
# Epoch 195/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.3953e-04 - mae: 0.0130 - val_loss: 3.5388e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 196/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 4.3728e-04 - mae: 0.0127 - val_loss: 3.5310e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 197/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.3649e-04 - mae: 0.0126 - val_loss: 3.5299e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 198/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.3671e-04 - mae: 0.0127 - val_loss: 3.5291e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 199/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.3674e-04 - mae: 0.0127 - val_loss: 3.5282e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 200/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 4.3537e-04 - mae: 0.0125 - val_loss: 3.5300e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 201/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 4.3433e-04 - mae: 0.0124 - val_loss: 3.5288e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 202/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 4.3701e-04 - mae: 0.0128 - val_loss: 3.5340e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 203/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 4.3686e-04 - mae: 0.0127 - val_loss: 3.5400e-04 - val_mae: 0.0019 - learning_rate: 1.0000e-06
# Epoch 204/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.3796e-04 - mae: 0.0129 - val_loss: 3.5419e-04 - val_mae: 0.0020 - learning_rate: 1.0000e-06
# Epoch 205/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.3829e-04 - mae: 0.0129 - val_loss: 3.5309e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 206/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.3722e-04 - mae: 0.0128 - val_loss: 3.5232e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 207/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.3134e-04 - mae: 0.0122 - val_loss: 3.5200e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 208/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.3805e-04 - mae: 0.0129 - val_loss: 3.5186e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 209/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.3556e-04 - mae: 0.0126 - val_loss: 3.5185e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 210/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.3620e-04 - mae: 0.0127 - val_loss: 3.5183e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 211/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.3360e-04 - mae: 0.0125 - val_loss: 3.5161e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 212/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.3594e-04 - mae: 0.0127 - val_loss: 3.5143e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 213/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.3804e-04 - mae: 0.0130 - val_loss: 3.5142e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 214/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.3649e-04 - mae: 0.0128 - val_loss: 3.5151e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 215/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.4136e-04 - mae: 0.0134 - val_loss: 3.5206e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 216/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.3628e-04 - mae: 0.0128 - val_loss: 3.5224e-04 - val_mae: 0.0017 - learning_rate: 1.0000e-06
# Epoch 217/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.3756e-04 - mae: 0.0130 - val_loss: 3.5192e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 218/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.2973e-04 - mae: 0.0122 - val_loss: 3.5119e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 219/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.3692e-04 - mae: 0.0129 - val_loss: 3.5113e-04 - val_mae: 0.0014 - learning_rate: 1.0000e-06
# Epoch 220/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.3213e-04 - mae: 0.0124 - val_loss: 3.5103e-04 - val_mae: 0.0014 - learning_rate: 1.0000e-06
# Epoch 221/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 4.3769e-04 - mae: 0.0130 - val_loss: 3.5084e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 222/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 4.3453e-04 - mae: 0.0127 - val_loss: 3.5059e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 223/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 4.3258e-04 - mae: 0.0125 - val_loss: 3.5051e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 224/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 4.3393e-04 - mae: 0.0126 - val_loss: 3.5042e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 225/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 4.3424e-04 - mae: 0.0127 - val_loss: 3.5056e-04 - val_mae: 0.0014 - learning_rate: 1.0000e-06
# Epoch 226/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.3364e-04 - mae: 0.0127 - val_loss: 3.5070e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 227/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.3629e-04 - mae: 0.0130 - val_loss: 3.5012e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 228/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.3388e-04 - mae: 0.0127 - val_loss: 3.5003e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 229/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.3348e-04 - mae: 0.0127 - val_loss: 3.4994e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 230/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.3551e-04 - mae: 0.0128 - val_loss: 3.4953e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 231/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.3249e-04 - mae: 0.0126 - val_loss: 3.4940e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 232/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.3245e-04 - mae: 0.0126 - val_loss: 3.4946e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 233/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.3506e-04 - mae: 0.0129 - val_loss: 3.4911e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 234/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.3476e-04 - mae: 0.0128 - val_loss: 3.4910e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 235/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.3302e-04 - mae: 0.0127 - val_loss: 3.4882e-04 - val_mae: 0.0011 - learning_rate: 1.0000e-06
# Epoch 236/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.3324e-04 - mae: 0.0127 - val_loss: 3.4905e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 237/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.3498e-04 - mae: 0.0129 - val_loss: 3.5010e-04 - val_mae: 0.0018 - learning_rate: 1.0000e-06
# Epoch 238/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.3125e-04 - mae: 0.0125 - val_loss: 3.5151e-04 - val_mae: 0.0025 - learning_rate: 1.0000e-06
# Epoch 239/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.3623e-04 - mae: 0.0130 - val_loss: 3.5066e-04 - val_mae: 0.0022 - learning_rate: 1.0000e-06
# Epoch 240/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.2934e-04 - mae: 0.0123 - val_loss: 3.4936e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 241/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.3178e-04 - mae: 0.0126 - val_loss: 3.4923e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 242/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.3225e-04 - mae: 0.0127 - val_loss: 3.4994e-04 - val_mae: 0.0020 - learning_rate: 1.0000e-06
# Epoch 243/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 4.2994e-04 - mae: 0.0125 - val_loss: 3.4900e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 244/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 4.3199e-04 - mae: 0.0127 - val_loss: 3.4942e-04 - val_mae: 0.0019 - learning_rate: 1.0000e-06
# Epoch 245/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 4.2628e-04 - mae: 0.0120 - val_loss: 3.5028e-04 - val_mae: 0.0023 - learning_rate: 1.0000e-06
# Epoch 246/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 4.3045e-04 - mae: 0.0125 - val_loss: 3.4982e-04 - val_mae: 0.0021 - learning_rate: 1.0000e-06
# Epoch 247/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.3131e-04 - mae: 0.0126 - val_loss: 3.4970e-04 - val_mae: 0.0021 - learning_rate: 1.0000e-06
# Epoch 248/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.3043e-04 - mae: 0.0126 - val_loss: 3.4984e-04 - val_mae: 0.0022 - learning_rate: 1.0000e-06
# Epoch 249/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.3408e-04 - mae: 0.0130 - val_loss: 3.5022e-04 - val_mae: 0.0024 - learning_rate: 1.0000e-06
# Epoch 250/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.2977e-04 - mae: 0.0125 - val_loss: 3.5028e-04 - val_mae: 0.0025 - learning_rate: 1.0000e-06
# Epoch 251/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.3074e-04 - mae: 0.0127 - val_loss: 3.4868e-04 - val_mae: 0.0019 - learning_rate: 1.0000e-06
# Epoch 252/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.3079e-04 - mae: 0.0126 - val_loss: 3.4904e-04 - val_mae: 0.0021 - learning_rate: 1.0000e-06
# Epoch 253/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.2827e-04 - mae: 0.0124 - val_loss: 3.4868e-04 - val_mae: 0.0020 - learning_rate: 1.0000e-06
# Epoch 254/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.3158e-04 - mae: 0.0127 - val_loss: 3.4828e-04 - val_mae: 0.0018 - learning_rate: 1.0000e-06
# Epoch 255/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.2828e-04 - mae: 0.0124 - val_loss: 3.4769e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 256/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.2998e-04 - mae: 0.0126 - val_loss: 3.4771e-04 - val_mae: 0.0017 - learning_rate: 1.0000e-06
# Epoch 257/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.3088e-04 - mae: 0.0127 - val_loss: 3.4759e-04 - val_mae: 0.0017 - learning_rate: 1.0000e-06
# Epoch 258/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.2738e-04 - mae: 0.0124 - val_loss: 3.4712e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 259/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.3353e-04 - mae: 0.0130 - val_loss: 3.4648e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 260/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.3131e-04 - mae: 0.0128 - val_loss: 3.4619e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 261/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.2670e-04 - mae: 0.0123 - val_loss: 3.4613e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 262/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.3194e-04 - mae: 0.0129 - val_loss: 3.4605e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 263/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.2986e-04 - mae: 0.0127 - val_loss: 3.4593e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 264/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 4.3162e-04 - mae: 0.0129 - val_loss: 3.4582e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 265/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 4.3369e-04 - mae: 0.0132 - val_loss: 3.4569e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 266/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 4.3004e-04 - mae: 0.0128 - val_loss: 3.4575e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 267/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 4.3281e-04 - mae: 0.0130 - val_loss: 3.4605e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 268/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 4.3130e-04 - mae: 0.0129 - val_loss: 3.4621e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 269/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 4.2592e-04 - mae: 0.0123 - val_loss: 3.4567e-04 - val_mae: 0.0014 - learning_rate: 1.0000e-06
# Epoch 270/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.2942e-04 - mae: 0.0128 - val_loss: 3.4522e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 271/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.2758e-04 - mae: 0.0125 - val_loss: 3.4506e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 272/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.3039e-04 - mae: 0.0129 - val_loss: 3.4557e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 273/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 4.2852e-04 - mae: 0.0127 - val_loss: 3.4534e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 274/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.2859e-04 - mae: 0.0127 - val_loss: 3.4469e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 275/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.2846e-04 - mae: 0.0127 - val_loss: 3.4452e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 276/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.2692e-04 - mae: 0.0125 - val_loss: 3.4460e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 277/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.2727e-04 - mae: 0.0126 - val_loss: 3.4501e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 278/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.3246e-04 - mae: 0.0131 - val_loss: 3.4579e-04 - val_mae: 0.0020 - learning_rate: 1.0000e-06
# Epoch 279/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.2670e-04 - mae: 0.0126 - val_loss: 3.4603e-04 - val_mae: 0.0021 - learning_rate: 1.0000e-06
# Epoch 280/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.3065e-04 - mae: 0.0130 - val_loss: 3.4689e-04 - val_mae: 0.0025 - learning_rate: 1.0000e-06
# Epoch 281/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.2675e-04 - mae: 0.0125 - val_loss: 3.4634e-04 - val_mae: 0.0023 - learning_rate: 1.0000e-06
# Epoch 282/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.2796e-04 - mae: 0.0128 - val_loss: 3.4575e-04 - val_mae: 0.0021 - learning_rate: 1.0000e-06
# Epoch 283/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.2537e-04 - mae: 0.0125 - val_loss: 3.4495e-04 - val_mae: 0.0018 - learning_rate: 1.0000e-06
# Epoch 284/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.2869e-04 - mae: 0.0128 - val_loss: 3.4440e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 285/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.2681e-04 - mae: 0.0126 - val_loss: 3.4386e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 286/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.2716e-04 - mae: 0.0127 - val_loss: 3.4406e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 287/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 4.2756e-04 - mae: 0.0128 - val_loss: 3.4445e-04 - val_mae: 0.0018 - learning_rate: 1.0000e-06
# Epoch 288/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 4.2690e-04 - mae: 0.0127 - val_loss: 3.4446e-04 - val_mae: 0.0019 - learning_rate: 1.0000e-06
# Epoch 289/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 4.2766e-04 - mae: 0.0127 - val_loss: 3.4437e-04 - val_mae: 0.0019 - learning_rate: 1.0000e-06
# Epoch 290/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 4.2572e-04 - mae: 0.0126 - val_loss: 3.4354e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 291/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.2511e-04 - mae: 0.0125 - val_loss: 3.4404e-04 - val_mae: 0.0019 - learning_rate: 1.0000e-06
# Epoch 292/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.2784e-04 - mae: 0.0128 - val_loss: 3.4369e-04 - val_mae: 0.0017 - learning_rate: 1.0000e-06
# Epoch 293/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.2434e-04 - mae: 0.0125 - val_loss: 3.4316e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 294/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.2765e-04 - mae: 0.0129 - val_loss: 3.4283e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 295/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.2389e-04 - mae: 0.0124 - val_loss: 3.4250e-04 - val_mae: 0.0014 - learning_rate: 1.0000e-06
# Epoch 296/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.3023e-04 - mae: 0.0131 - val_loss: 3.4266e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 297/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.2504e-04 - mae: 0.0126 - val_loss: 3.4300e-04 - val_mae: 0.0017 - learning_rate: 1.0000e-06
# Epoch 298/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.2151e-04 - mae: 0.0122 - val_loss: 3.4339e-04 - val_mae: 0.0019 - learning_rate: 1.0000e-06
# Epoch 299/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.2245e-04 - mae: 0.0123 - val_loss: 3.4418e-04 - val_mae: 0.0023 - learning_rate: 1.0000e-06
# Epoch 300/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.2365e-04 - mae: 0.0125 - val_loss: 3.4248e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 301/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.2513e-04 - mae: 0.0127 - val_loss: 3.4164e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 302/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.2565e-04 - mae: 0.0127 - val_loss: 3.4132e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 303/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.2022e-04 - mae: 0.0122 - val_loss: 3.4118e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 304/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.2719e-04 - mae: 0.0129 - val_loss: 3.4134e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 305/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.1980e-04 - mae: 0.0121 - val_loss: 3.4123e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 306/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.2292e-04 - mae: 0.0125 - val_loss: 3.4111e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 307/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.2539e-04 - mae: 0.0127 - val_loss: 3.4079e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 308/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 4.2273e-04 - mae: 0.0125 - val_loss: 3.4055e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 309/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.2194e-04 - mae: 0.0124 - val_loss: 3.4032e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 310/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 4.2791e-04 - mae: 0.0130 - val_loss: 3.4038e-04 - val_mae: 0.0014 - learning_rate: 1.0000e-06
# Epoch 311/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 4.2194e-04 - mae: 0.0125 - val_loss: 3.4007e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 312/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 4.2426e-04 - mae: 0.0127 - val_loss: 3.4043e-04 - val_mae: 0.0014 - learning_rate: 1.0000e-06
# Epoch 313/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.2032e-04 - mae: 0.0123 - val_loss: 3.4107e-04 - val_mae: 0.0018 - learning_rate: 1.0000e-06
# Epoch 314/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.2569e-04 - mae: 0.0129 - val_loss: 3.4182e-04 - val_mae: 0.0021 - learning_rate: 1.0000e-06
# Epoch 315/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.2357e-04 - mae: 0.0127 - val_loss: 3.4257e-04 - val_mae: 0.0025 - learning_rate: 1.0000e-06
# Epoch 316/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.2057e-04 - mae: 0.0124 - val_loss: 3.4088e-04 - val_mae: 0.0018 - learning_rate: 1.0000e-06
# Epoch 317/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.2237e-04 - mae: 0.0126 - val_loss: 3.4017e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 318/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.2497e-04 - mae: 0.0128 - val_loss: 3.4084e-04 - val_mae: 0.0019 - learning_rate: 1.0000e-06
# Epoch 319/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.2035e-04 - mae: 0.0124 - val_loss: 3.3997e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 320/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.2549e-04 - mae: 0.0129 - val_loss: 3.3952e-04 - val_mae: 0.0014 - learning_rate: 1.0000e-06
# Epoch 321/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.2445e-04 - mae: 0.0128 - val_loss: 3.3910e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 322/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.1945e-04 - mae: 0.0123 - val_loss: 3.3911e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 323/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.1920e-04 - mae: 0.0123 - val_loss: 3.3908e-04 - val_mae: 0.0014 - learning_rate: 1.0000e-06
# Epoch 324/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.2661e-04 - mae: 0.0131 - val_loss: 3.3859e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 325/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.1843e-04 - mae: 0.0123 - val_loss: 3.3869e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 326/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.2166e-04 - mae: 0.0127 - val_loss: 3.3839e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 327/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.2336e-04 - mae: 0.0128 - val_loss: 3.3826e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 328/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.2019e-04 - mae: 0.0125 - val_loss: 3.3853e-04 - val_mae: 0.0014 - learning_rate: 1.0000e-06
# Epoch 329/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 4.2400e-04 - mae: 0.0128 - val_loss: 3.3868e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 330/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 4.1908e-04 - mae: 0.0124 - val_loss: 3.3888e-04 - val_mae: 0.0017 - learning_rate: 1.0000e-06
# Epoch 331/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 4.2517e-04 - mae: 0.0130 - val_loss: 3.3903e-04 - val_mae: 0.0018 - learning_rate: 1.0000e-06
# Epoch 332/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 4.1951e-04 - mae: 0.0125 - val_loss: 3.3884e-04 - val_mae: 0.0017 - learning_rate: 1.0000e-06
# Epoch 333/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 4.1787e-04 - mae: 0.0123 - val_loss: 3.3808e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 334/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.2016e-04 - mae: 0.0125 - val_loss: 3.3794e-04 - val_mae: 0.0014 - learning_rate: 1.0000e-06
# Epoch 335/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.2078e-04 - mae: 0.0126 - val_loss: 3.3796e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 336/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.1998e-04 - mae: 0.0126 - val_loss: 3.3739e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 337/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.1477e-04 - mae: 0.0120 - val_loss: 3.3716e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 338/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.1847e-04 - mae: 0.0124 - val_loss: 3.3737e-04 - val_mae: 0.0014 - learning_rate: 1.0000e-06
# Epoch 339/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.2200e-04 - mae: 0.0128 - val_loss: 3.3792e-04 - val_mae: 0.0017 - learning_rate: 1.0000e-06
# Epoch 340/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.1868e-04 - mae: 0.0125 - val_loss: 3.3779e-04 - val_mae: 0.0017 - learning_rate: 1.0000e-06
# Epoch 341/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.1977e-04 - mae: 0.0126 - val_loss: 3.3800e-04 - val_mae: 0.0019 - learning_rate: 1.0000e-06
# Epoch 342/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.1961e-04 - mae: 0.0126 - val_loss: 3.3815e-04 - val_mae: 0.0020 - learning_rate: 1.0000e-06
# Epoch 343/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.2138e-04 - mae: 0.0128 - val_loss: 3.3889e-04 - val_mae: 0.0024 - learning_rate: 1.0000e-06
# Epoch 344/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.1779e-04 - mae: 0.0124 - val_loss: 3.3768e-04 - val_mae: 0.0019 - learning_rate: 1.0000e-06
# Epoch 345/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.2104e-04 - mae: 0.0128 - val_loss: 3.3757e-04 - val_mae: 0.0019 - learning_rate: 1.0000e-06
# Epoch 346/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.1732e-04 - mae: 0.0124 - val_loss: 3.3692e-04 - val_mae: 0.0017 - learning_rate: 1.0000e-06
# Epoch 347/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.1852e-04 - mae: 0.0126 - val_loss: 3.3670e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 348/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.1685e-04 - mae: 0.0124 - val_loss: 3.3588e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 349/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.2261e-04 - mae: 0.0130 - val_loss: 3.3541e-04 - val_mae: 0.0011 - learning_rate: 1.0000e-06
# Epoch 350/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 4.1736e-04 - mae: 0.0125 - val_loss: 3.3523e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 351/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 4.1885e-04 - mae: 0.0126 - val_loss: 3.3511e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 352/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 4.1843e-04 - mae: 0.0126 - val_loss: 3.3500e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 353/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 4.1928e-04 - mae: 0.0127 - val_loss: 3.3510e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 354/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.1840e-04 - mae: 0.0126 - val_loss: 3.3485e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 355/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 4.2108e-04 - mae: 0.0130 - val_loss: 3.3463e-04 - val_mae: 0.0011 - learning_rate: 1.0000e-06
# Epoch 356/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.1688e-04 - mae: 0.0125 - val_loss: 3.3451e-04 - val_mae: 0.0011 - learning_rate: 1.0000e-06
# Epoch 357/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.1713e-04 - mae: 0.0126 - val_loss: 3.3438e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 358/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.2017e-04 - mae: 0.0129 - val_loss: 3.3428e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 359/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.1554e-04 - mae: 0.0124 - val_loss: 3.3436e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 360/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.1736e-04 - mae: 0.0126 - val_loss: 3.3435e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 361/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.2001e-04 - mae: 0.0129 - val_loss: 3.3421e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 362/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 4.1964e-04 - mae: 0.0129 - val_loss: 3.3408e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 363/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.1429e-04 - mae: 0.0123 - val_loss: 3.3377e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 364/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.1824e-04 - mae: 0.0127 - val_loss: 3.3364e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 365/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.1531e-04 - mae: 0.0124 - val_loss: 3.3355e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 366/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.1871e-04 - mae: 0.0128 - val_loss: 3.3352e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 367/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.1600e-04 - mae: 0.0125 - val_loss: 3.3335e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 368/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.1717e-04 - mae: 0.0127 - val_loss: 3.3339e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 369/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.1401e-04 - mae: 0.0124 - val_loss: 3.3346e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 370/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.1720e-04 - mae: 0.0127 - val_loss: 3.3304e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 371/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 4.1880e-04 - mae: 0.0129 - val_loss: 3.3283e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 372/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 4.1738e-04 - mae: 0.0127 - val_loss: 3.3283e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 373/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 4.1991e-04 - mae: 0.0130 - val_loss: 3.3296e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 374/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.1813e-04 - mae: 0.0129 - val_loss: 3.3402e-04 - val_mae: 0.0019 - learning_rate: 1.0000e-06
# Epoch 375/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.1648e-04 - mae: 0.0127 - val_loss: 3.3380e-04 - val_mae: 0.0018 - learning_rate: 1.0000e-06
# Epoch 376/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.1445e-04 - mae: 0.0125 - val_loss: 3.3306e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 377/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.1733e-04 - mae: 0.0128 - val_loss: 3.3301e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 378/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.1459e-04 - mae: 0.0125 - val_loss: 3.3242e-04 - val_mae: 0.0014 - learning_rate: 1.0000e-06
# Epoch 379/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.1713e-04 - mae: 0.0128 - val_loss: 3.3206e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 380/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.1339e-04 - mae: 0.0125 - val_loss: 3.3213e-04 - val_mae: 0.0014 - learning_rate: 1.0000e-06
# Epoch 381/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.1011e-04 - mae: 0.0121 - val_loss: 3.3278e-04 - val_mae: 0.0017 - learning_rate: 1.0000e-06
# Epoch 382/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.1450e-04 - mae: 0.0126 - val_loss: 3.3312e-04 - val_mae: 0.0019 - learning_rate: 1.0000e-06
# Epoch 383/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.1759e-04 - mae: 0.0129 - val_loss: 3.3228e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 384/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.1671e-04 - mae: 0.0128 - val_loss: 3.3149e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 385/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.1490e-04 - mae: 0.0127 - val_loss: 3.3131e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 386/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.1421e-04 - mae: 0.0126 - val_loss: 3.3122e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 387/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.1777e-04 - mae: 0.0130 - val_loss: 3.3122e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 388/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.1090e-04 - mae: 0.0123 - val_loss: 3.3207e-04 - val_mae: 0.0018 - learning_rate: 1.0000e-06
# Epoch 389/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 4.1773e-04 - mae: 0.0130 - val_loss: 3.3153e-04 - val_mae: 0.0016 - learning_rate: 1.0000e-06
# Epoch 390/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.1157e-04 - mae: 0.0124 - val_loss: 3.3121e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 391/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 4.1640e-04 - mae: 0.0129 - val_loss: 3.3078e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 392/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 4.1191e-04 - mae: 0.0124 - val_loss: 3.3031e-04 - val_mae: 0.0012 - learning_rate: 1.0000e-06
# Epoch 393/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 4.1403e-04 - mae: 0.0126 - val_loss: 3.3026e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 394/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 4.1651e-04 - mae: 0.0129 - val_loss: 3.3064e-04 - val_mae: 0.0014 - learning_rate: 1.0000e-06
# Epoch 395/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 4.1239e-04 - mae: 0.0125 - val_loss: 3.3017e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 396/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.1171e-04 - mae: 0.0124 - val_loss: 3.2994e-04 - val_mae: 0.0013 - learning_rate: 1.0000e-06
# Epoch 397/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.1351e-04 - mae: 0.0127 - val_loss: 3.3046e-04 - val_mae: 0.0015 - learning_rate: 1.0000e-06
# Epoch 398/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.1237e-04 - mae: 0.0125 - val_loss: 3.3283e-04 - val_mae: 0.0025 - learning_rate: 1.0000e-06
# Epoch 399/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.0910e-04 - mae: 0.0123 - val_loss: 3.3159e-04 - val_mae: 0.0021 - learning_rate: 1.0000e-06
# Epoch 400/400
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.1240e-04 - mae: 0.0126 - val_loss: 3.3163e-04 - val_mae: 0.0022 - learning_rate: 1.0000e-06
# Restoring model weights from the end of the best epoch: 396.
#
# ✅ Entraînement terminé

# %%
from sklearn.linear_model import LinearRegression

# Fit on TRAIN only — captures both scale and offset error
#soh_pred_train = model.predict(X_train, verbose=0).flatten()
#calib = LinearRegression().fit(soh_pred_train.reshape(-1, 1), y_train)

#print(f'Pente (a)     : {calib.coef_[0]:.4f}')
#print(f'Intercept (b) : {calib.intercept_:.4f}')

# %% [markdown]
# ## 12 — Prédiction
#
# Pas d'`inverse_transform` — la prédiction est directement dans l'espace SOH réel.

# %%
soh_pred  = model.predict(X_val, verbose=0).flatten().reshape(-1, 1)
soh_true  = y_val

print(f'SOH prédit (calibré) → min={soh_pred.min():.4f}  max={soh_pred.max():.4f}')
print(f'SOH réel             → min={soh_true.min():.4f}  max={soh_true.max():.4f}')
print('✅ Prédiction calibrée terminée')
# Out:
# SOH prédit (calibré) → min=0.7014  max=0.7558
# SOH réel             → min=0.7001  max=0.7576
# ✅ Prédiction calibrée terminée

# %%
print("Pred mean:", np.mean(soh_pred))
print("Pred std :", np.std(soh_pred))
# Out:
# Pred mean: 0.72908664
# Pred std : 0.015091929

# %% [markdown]
# ## 13 — Évaluation

# %%
mse   = mean_squared_error(soh_true, soh_pred)
rmse  = np.sqrt(mse)
mae   = mean_absolute_error(soh_true, soh_pred)
r2    = r2_score(soh_true, soh_pred)
evs   = explained_variance_score(soh_true, soh_pred)
me    = max_error(soh_true, soh_pred)
medae = np.median(np.abs(soh_true - soh_pred))
mask  = soh_true != 0
mape  = np.mean(np.abs((soh_true[mask]-soh_pred[mask])/soh_true[mask]))*100
smape = np.mean(2*np.abs(soh_true-soh_pred)/
                (np.abs(soh_true)+np.abs(soh_pred)+1e-8))*100

sep = '='*54
print(sep)
print('  ÉVALUATION — SOH direct (espace réel)')
print(sep)
print(f'  MAE  calibré     : {mean_absolute_error(soh_true, soh_pred)*100:.3f}% SOH')
print(f'  RMSE             : {rmse:.6f}  ({rmse*100:.3f} % SOH)')
print(f'  MAPE             : {mape:.4f} %')
print(f'  SMAPE            : {smape:.4f} %')
print(f'  Median Abs Error : {medae:.6f}')
print(f'  Max Error        : {me:.6f}')
print(f'  R²   calibré     : {r2_score(soh_true, soh_pred):.4f}')
print(f'  Explained Var    : {evs:.6f}')
print(sep)
# Out:
# ======================================================
#   ÉVALUATION — SOH direct (espace réel)
# ======================================================
#   MAE  calibré     : 0.128% SOH
#   RMSE             : 0.001648  (0.165 % SOH)
#   MAPE             : 2.4879 %
#   SMAPE            : 2.4854 %
#   Median Abs Error : 0.015909
#   Max Error        : 0.004855
#   R²   calibré     : 0.9897
#   Explained Var    : 0.990136
# ======================================================

# %% [markdown]
# ## 14 — Visualisations

# %%
fig, axes = plt.subplots(1, 2, figsize=(13, 4))
axes[0].plot(history.history['loss'],     label='Train', lw=1.5)
axes[0].plot(history.history['val_loss'], label='Val',   lw=1.5, ls='--')
axes[0].set(xlabel='Époque', ylabel='MSE', title='Loss MSE — SOH brut [0,1]')
axes[0].legend(); axes[0].grid(alpha=0.3)

axes[1].plot(history.history['mae'],     label='Train', lw=1.5)
axes[1].plot(history.history['val_mae'], label='Val',   lw=1.5, ls='--')
axes[1].set(xlabel='Époque', ylabel='MAE', title='Loss MAE — SOH brut [0,1]')
axes[1].legend(); axes[1].grid(alpha=0.3)

plt.tight_layout()
plt.savefig(f'{OUTPUT_DIR}/loss_curves.png', dpi=150, bbox_inches='tight')
plt.show()
print('✅ loss_curves.png')
# Out:
# ✅ loss_curves.png

# %%
plt.figure(figsize=(13, 4))
plt.plot(soh_true, label='SOH réel',   lw=1.5, color='steelblue')
plt.plot(soh_pred, label='SOH prédit', lw=1.5, ls='--', color='tomato')
plt.xlabel('Séquence (val set)')
plt.ylabel('SOH')
plt.title(f'SOH réel vs prédit  (MAE={mae:.4f}, R²={r2:.4f})')
plt.legend(); plt.grid(alpha=0.3); plt.tight_layout()
plt.savefig(f'{OUTPUT_DIR}/soh_pred_vs_true.png', dpi=150, bbox_inches='tight')
plt.show()
print('✅ soh_pred_vs_true.png')
# Out:
# ✅ soh_pred_vs_true.png

# %%
fig, axes = plt.subplots(1, 2, figsize=(11, 4))

axes[0].scatter(soh_true, soh_pred, alpha=0.3, s=8, color='steelblue')
lims = [min(soh_true.min(),soh_pred.min())-0.005, max(soh_true.max(),soh_pred.max())+0.005]
axes[0].plot(lims, lims, 'r--', lw=1.5, label='Parfait')
axes[0].set(xlim=lims, ylim=lims, xlabel='SOH réel', ylabel='SOH prédit',
            title=f'Scatter (R²={r2:.4f})')
axes[0].legend(); axes[0].grid(alpha=0.3)

residuals = soh_pred - soh_true


plt.tight_layout()
plt.savefig(f'{OUTPUT_DIR}/scatter_residuals.png', dpi=150, bbox_inches='tight')
plt.show()
print('✅ scatter_residuals.png')
# Out:
# ✅ scatter_residuals.png

# %%
abs_err = np.abs(soh_pred - soh_true)
plt.figure(figsize=(13, 3))
plt.plot(abs_err, lw=1, color='tomato', alpha=0.8)
plt.axhline(mae, color='red', lw=1.5, ls='--', label=f'MAE = {mae:.4f}')
plt.xlabel('Séquence (val set)'); plt.ylabel('|SOH_pred − SOH_true|')
plt.title('Erreur absolue au fil des cycles')
plt.legend(); plt.grid(alpha=0.3); plt.tight_layout()
plt.savefig(f'{OUTPUT_DIR}/abs_error.png', dpi=150, bbox_inches='tight')
plt.show()
print('✅ abs_error.png')
# Out:
# ✅ abs_error.png

# %% [markdown]
# ## 15 — Sauvegarde

# %%
model.save(f'{OUTPUT_DIR}/cubesat_soh_lstm_v3_unroll_True.keras')
joblib.dump(scaler_X, f'{OUTPUT_DIR}/scaler_X.pkl')
#joblib.dump(bias, f'{OUTPUT_DIR}/bias_correction.pkl')
with open(f'{OUTPUT_DIR}/features_used.pkl', 'wb') as f:
    pickle.dump(FEATURE_COLS, f)
pd.DataFrame([{
    'MAE': mae, 'RMSE': rmse, 'MAPE': mape, 'SMAPE': smape,
    'MedianAE': medae, 'MaxError': me, 'R2': r2, 'ExplainedVariance': evs,
    'target': 'SOH_raw', 'n_features': len(FEATURE_COLS),
    'window': WINDOW_SIZE, 'horizon': HORIZON,
    'train_cycles': len(train_df), 'val_cycles': len(val_df),
}]).to_csv(f'{OUTPUT_DIR}/metrics.csv', index=False)
print(f'✅ Artefacts → {OUTPUT_DIR}/')
for fn in sorted(os.listdir(OUTPUT_DIR)):
    print(f'  {fn:<40} {os.path.getsize(f"{OUTPUT_DIR}/{fn}"):>10,} bytes')
# Out:
# ✅ Artefacts → /content/drive/MyDrive/Colab Notebooks/outputs_1/
#   abs_error.png                               143,913 bytes
#   cubesat_soh_lstm.keras                    1,855,224 bytes
#   cubesat_soh_lstm_unrolled.keras           1,855,222 bytes
#   cubesat_soh_lstm_v3_optimized.keras         505,496 bytes
#   cubesat_soh_lstm_v3_unroll_False.keras      505,494 bytes
#   cubesat_soh_lstm_v3_unroll_True.keras       505,103 bytes
#   features_used.pkl                               293 bytes
#   loss_curves.png                              73,806 bytes
#   metrics.csv                                     268 bytes
#   raw_features.csv                          2,238,442 bytes
#   scaler_X.pkl                                  1,623 bytes
#   scatter_residuals.png                        74,063 bytes
#   soh_pred_vs_true.png                         84,187 bytes
